# %%
import numpy as np 
import pandas as pd

# %%
df_train = pd.read_csv('Paitients_Files_Train.csv')
df_train.head()
# Out:
#           ID  PRG   PL  PR  SK   TS   M11    BD2  Age  Insurance   Sepssis
# 0  ICU200010    6  148  72  35    0  33.6  0.627   50          0  Positive
# 1  ICU200011    1   85  66  29    0  26.6  0.351   31          0  Negative
# 2  ICU200012    8  183  64   0    0  23.3  0.672   32          1  Positive
# 3  ICU200013    1   89  66  23   94  28.1  0.167   21          1  Negative
# 4  ICU200014    0  137  40  35  168  43.1  2.288   33          1  Positive

# %%
df_train['sepsis_encoded'] = df_train['Sepssis'].map({'Positive':1, 'Negative': 0})
df_train = df_train.drop(['ID', 'Sepssis'], axis='columns')
df_train.head()
# Out:
#    PRG   PL  PR  SK   TS   M11    BD2  Age  Insurance  sepsis_encoded
# 0    6  148  72  35    0  33.6  0.627   50          0               1
# 1    1   85  66  29    0  26.6  0.351   31          0               0
# 2    8  183  64   0    0  23.3  0.672   32          1               1
# 3    1   89  66  23   94  28.1  0.167   21          1               0
# 4    0  137  40  35  168  43.1  2.288   33          1               1

# %%
df_train['sepsis_encoded'].value_counts()
# Out:
# sepsis_encoded
# 0    391
# 1    208
# Name: count, dtype: int64

# %%
X = df_train.iloc[:,:-1]
y = df_train.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=2023)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((479, 9), (120, 9), (479,), (120,))

# %% [markdown]
# # Optuna

# %%
import optuna
from xgboost import XGBClassifier
from sklearn.model_selection import cross_val_score

# %%
def objective(trial):
    learning_rate = trial.suggest_uniform('learning_rate', 0.01, 1)
    max_depth = trial.suggest_int('max_depth', 2, 11)
    n_estimators = trial.suggest_int('n_estimators', 50, 200)
    min_child_weight = trial.suggest_int('min_child_weight', 1, 10)
    gamma = trial.suggest_uniform('gamma', 0.01, 5)
    subsample = trial.suggest_uniform('subsample', 0.01, 1)
    clf1 = XGBClassifier(learning_rate=learning_rate,
                         max_depth=max_depth,
                         n_estimators=n_estimators,
                         min_child_weight=min_child_weight,
                         gamma=gamma)
    score = cross_val_score(clf1, X_train, y_train, cv=5)
    return np.mean(score)

# %%
study = optuna.create_study(direction='maximize',sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=30)
study.best_params
# Out:
# [I 2025-04-04 18:46:56,554] A new study created in memory with name: no-name-bf2ac0cc-75a1-45fc-8bc2-1ae7a5e9940a
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:2: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 1)
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   gamma = trial.suggest_uniform('gamma', 0.01, 5)
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.01, 1)
# [I 2025-04-04 18:46:58,621] Trial 0 finished with value: 0.7328070175438597 and parameters: {'learning_rate': 0.3807947176588889, 'max_depth': 11, 'n_estimators': 160, 'min_child_weight': 6, 'gamma': 0.7885330158077583, 'subsample': 0.16443457513284063}. Best is trial 0 with value: 0.7328070175438597.
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:2: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 1)
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   gamma = trial.suggest_uniform('gamma', 0.01, 5)
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.01, 1)
# [I 2025-04-04 18:47:02,298] Trial 1 finished with value: 0.7494956140350877 and parameters: {'learning_rate': 0.06750277604651747, 'max_depth': 10, 'n_estimators': 140, 'min_child_weight': 8, 'gamma': 0.11271662653605422, 'subsample': 0.9702107536403743}. Best is trial 1 with value: 0.7494956140350877.
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:2: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 1)
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   gamma = trial.suggest_uniform('gamma', 0.01, 5)
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.01, 1)
# [I 2025-04-04 18:47:03,156] Trial 2 finished with value: 0.7618859649122807 and parameters: {'learning_rate': 0.8341182143924175, 'max_depth': 4, 'n_estimators': 77, 'min_child_weight': 2, 'gamma': 1.5281687923680933, 'subsample': 0.5295088673159155}. Best is trial 2 with value: 0.7618859649122807.
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:2: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 1)
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   gamma = trial.suggest_uniform('gamma', 0.01, 5)
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.01, 1)
# [I 2025-04-04 18:47:04,742] Trial 3 finished with value: 0.7536622807017545 and parameters: {'learning_rate': 0.4376255684556946, 'max_depth': 4, 'n_estimators': 142, 'min_child_weight': 2, 'gamma': 1.4678017961907386, 'subsample': 0.37269822486075477}. Best is trial 2 with value: 0.7618859649122807.
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:2: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 1)
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   gamma = trial.suggest_uniform('gamma', 0.01, 5)
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.01, 1)
# [I 2025-04-04 18:47:05,762] Trial 4 finished with value: 0.7640570175438597 and parameters: {'learning_rate': 0.46150928437486555, 'max_depth': 9, 'n_estimators': 80, 'min_child_weight': 6, 'gamma': 2.9661486986215917, 'subsample': 0.05598590859279775}. Best is trial 4 with value: 0.7640570175438597.
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:2: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 1)
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   gamma = trial.suggest_uniform('gamma', 0.01, 5)
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.01, 1)
# [I 2025-04-04 18:47:06,581] Trial 5 finished with value: 0.7619736842105264 and parameters: {'learning_rate': 0.611469403382424, 'max_depth': 3, 'n_estimators': 59, 'min_child_weight': 10, 'gamma': 4.828503845042051, 'subsample': 0.8103133746352965}. Best is trial 4 with value: 0.7640570175438597.
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:2: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 1)
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   gamma = trial.suggest_uniform('gamma', 0.01, 5)
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.01, 1)
# [I 2025-04-04 18:47
. Best is trial 14 with value: 0.7640789473684212.
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:2: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 1)
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   gamma = trial.suggest_uniform('gamma', 0.01, 5)
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.01, 1)
# [I 2025-04-04 18:47:30,282] Trial 20 finished with value: 0.7389912280701754 and parameters: {'learning_rate': 0.8802506097673074, 'max_depth': 8, 'n_estimators': 51, 'min_child_weight': 7, 'gamma': 2.070134019474728, 'subsample': 0.25068553788912673}. Best is trial 14 with value: 0.7640789473684212.
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:2: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 1)
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   gamma = trial.suggest_uniform('gamma', 0.01, 5)
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.01, 1)
# [I 2025-04-04 18:47:32,150] Trial 21 finished with value: 0.7557675438596491 and parameters: {'learning_rate': 0.5532161505186944, 'max_depth': 2, 'n_estimators': 200, 'min_child_weight': 8, 'gamma': 4.340939608466772, 'subsample': 0.6745245976770464}. Best is trial 14 with value: 0.7640789473684212.
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:2: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 1)
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   gamma = trial.suggest_uniform('gamma', 0.01, 5)
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.01, 1)
# [I 2025-04-04 18:47:33,848] Trial 22 finished with value: 0.7452192982456141 and parameters: {'learning_rate': 0.6928741489326259, 'max_depth': 5, 'n_estimators': 178, 'min_child_weight': 9, 'gamma': 2.992836749523984, 'subsample': 0.8574873650374845}. Best is trial 14 with value: 0.7640789473684212.
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:2: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 1)
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   gamma = trial.suggest_uniform('gamma', 0.01, 5)
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.01, 1)
# [I 2025-04-04 18:47:35,978] Trial 23 finished with value: 0.7619736842105264 and parameters: {'learning_rate': 0.23487039200804236, 'max_depth': 4, 'n_estimators': 185, 'min_child_weight': 9, 'gamma': 2.058339177614446, 'subsample': 0.42551240785466504}. Best is trial 14 with value: 0.7640789473684212.
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:2: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 1)
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   gamma = trial.suggest_uniform('gamma', 0.01, 5)
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.01, 1)
# [I 2025-04-04 18:47:37,917] Trial 24 finished with value: 0.7327850877192982 and parameters: {'learning_rate': 0.641065960626074, 'max_depth': 3, 'n_estimators': 164, 'min_child_weight': 7, 'gamma': 4.38889851788009, 'subsample': 0.6127581823184836}. Best is trial 14 with value: 0.7640789473684212.
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:2: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 1)
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   gamma = trial.suggest_uniform('gamma', 0.01, 5)
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.01, 1)
# [I 2025-04-04 18:47:39,478] Trial 25 finished with value: 0.7536184210526315 and parameters: {'learning_rate': 0.47495656981301265, 'max_depth': 5, 'n_estimators': 131, 'min_child_weight': 6, 'gamma': 3.598890005707906, 'subsample': 0.10630699216416853}. Best is trial 14 with value: 0.7640789473684212.
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:2: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 1)
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   gamma = trial.suggest_uniform('gamma', 0.01, 5)
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.01, 1)
# [I 2025-04-04 18:47:40,982] Trial 26 finished with value: 0.7536403508771929 and parameters: {'learning_rate': 0.33928064716862855, 'max_depth': 9, 'n_estimators': 151, 'min_child_weight': 8, 'gamma': 2.9624209866021554, 'subsample': 0.2561009056491125}. Best is trial 14 with value: 0.7640789473684212.
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:2: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 1)
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   gamma = trial.suggest_uniform('gamma', 0.01, 5)
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.01, 1)
# [I 2025-04-04 18:47:42,768] Trial 27 finished with value: 0.7452850877192982 and parameters: {'learning_rate': 0.7862207110318208, 'max_depth': 10, 'n_estimators': 183, 'min_child_weight': 9, 'gamma': 3.8870919780342965, 'subsample': 0.01527510520828349}. Best is trial 14 with value: 0.7640789473684212.
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:2: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 1)
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   gamma = trial.suggest_uniform('gamma', 0.01, 5)
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.01, 1)
# [I 2025-04-04 18:47:44,215] Trial 28 finished with value: 0.7598684210526316 and parameters: {'learning_rate': 0.5030827785603403, 'max_depth': 6, 'n_estimators': 115, 'min_child_weight': 5, 'gamma': 2.3405523420707044, 'subsample': 0.8525030848685566}. Best is trial 14 with value: 0.7640789473684212.
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:2: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 1)
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   gamma = trial.suggest_uniform('gamma', 0.01, 5)
# C:\Users\Prakash\AppData\Local\Temp\ipykernel_8892\393785304.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.01, 1)
# [I 2025-04-04 18:47:46,121] Trial 29 finished with value: 0.7411184210526316 and parameters: {'learning_rate': 0.3926029311649249, 'max_depth': 3, 'n_estimators': 170, 'min_child_weight': 6, 'gamma': 1.0187737372924188, 'subsample': 0.10650324217557851}. Best is trial 14 with value: 0.7640789473684212.
# {'learning_rate': 0.7742047722562706,
#  'max_depth': 6,
#  'n_estimators': 173,
#  'min_child_weight': 8,
#  'gamma': 2.63094119499456,
#  'subsample': 0.01292237593906475}

# %%
xgbc = XGBClassifier(learning_rate= list(study.best_params.values())[0],
 max_depth= list(study.best_params.values())[1],
 n_estimators= list(study.best_params.values())[2],
 min_child_weight= list(study.best_params.values())[3],
 gamma= list(study.best_params.values())[4],
 subsample= list(study.best_params.values())[5]
                     )

# %%
from sklearn.metrics import classification_report

# %%
xgbc.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=2.63094119499456, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.7742047722562706,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=8, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=173, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
y_predicted = xgbc.predict(X_test)

# %%
print(classification_report(y_test, y_predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.65      1.00      0.79        78
#            1       0.00      0.00      0.00        42
#
#     accuracy                           0.65       120
#    macro avg       0.33      0.50      0.39       120
# weighted avg       0.42      0.65      0.51       120
# C:\Users\Prakash\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Prakash\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Prakash\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# **I also tried using standardization and SMOTE, but the ACCURACY was low. I wonder why?**
